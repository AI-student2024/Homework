# %% [markdown]
# # 构造微调训练数据集

# %% [markdown]
# #### 借助 ChatGPT 和 GPT API 我们可以实现自动化批量构造训练数据集。

# %% [markdown]
# #### 下面我们以中国古典哲学数据集为例，展示了自动构造训练集的主要流程：

# %% [markdown]
# #### 使用 LangChain 构造训练数据样例
#    - 基于 ChatGPT 设计 System Role 提示词
#    - 使用 OpenAI GPT-3.5-Turbo-1106 生成基础数据
#    - 解析 OpenAI GPT 生成的训练数据
#    - 持久化存储dataset.csv训练数据集文件
#    - 使用 ChatGPT 实现训练数据多样化

# %% [markdown]
# #### 自动化批量生成训练数据集
#   - 整理收集原始数据raw_data.txt
#   - 自动解析原始数据样例 raw_data_content[]
#   - 设计 gen_data 训练数据生成器函数
#   - 设计训练数据生成流水线

# %% [markdown]
# ### 最佳实践参考：

# %% [markdown]
#   - 使用 GPT-3.5 生成基础数据：https://platform.openai.com/playground/p/2c7XNPgo6Y2iDxILiWfD3iPu?model=gpt-3.5-turbo-1106&mode=chat
#   - 使用 ChatGPT 生成数据处理代码和相关文本整理：https://chat.openai.com/share/cdfd2d1d-a75e-4cee-be49-539c010ca1b1
#   - GPT API 价格: https://openai.com/pricing

# %% [markdown]
# ## 使用 OpenAI SDk 构造训练数据

# %% [raw]
# # 导入openai的python客户端（需要将ubuntu系统中的openai进行降级，使用pip install openai==0.28.0，安装一个旧版本的openai的python客户端）
# import openai
#
# # 设置您的 API 密钥
# openai.api_key = 'OPENAI_API_KEY' # 需要从openai官网获取：https://platform.openai.com/api-keys PS：建议设置到环境变量文件~/.bashrc中。
#
# # 定义请求参数
# request_params = {
#     "model": "babbage-002",  # openai官网提供了可用于测试的模型及示例代码:https://platform.openai.com/docs/api-reference/assistants/createAssistant
#     "prompt": "Say this is a test",
#     "max_tokens": 7,
#     "temperature": 0
# }
#
# # 发起请求
# response = openai.Completion.create(**request_params)
#
# # 打印返回结果，测试是否成功调用api-key
# print(response)

# %% [markdown]
# #### response输出的代码含义解读：

# %% [raw]
# {
#   "id": "cmpl-8xRcAuaqKtdmDsq0zlPbhrOss4hRN",  // 模型输出的唯一标识符
#   "object": "text_completion",  // 输出的对象类型为文本完成
#   "created": 1709178194,  // 输出创建的时间戳
#   "model": "babbage-002",  // 使用的模型名称
#   "choices": [  // 可选项列表
#     {
#       "text": ", I'm gonna do it.",  // 完成的文本内容，模型输出结果
#       "index": 0,  // 选项的索引号
#       "logprobs": null,  // 对数概率信息（在此处为null）
#       "finish_reason": "length"  // 完成原因（在此处为长度达到限制）
#     }
#   ],
#   "usage": {  // 使用统计信息
#     "prompt_tokens": 5,  // 提示标记数
#     "completion_tokens": 7,  // 完成标记数，即模型输出结果的tokens数量，逗号、句号都计算为1个token。
#     "total_tokens": 12  // 总标记数
#   }
# }

# %%
from openai import OpenAI
client = OpenAI()

# %%
response = client.chat.completions.create(
  model="gpt-3.5-turbo-1106",
  messages=[
    {
      "role": "system",
      "content": "你是中国古典哲学大师，尤其擅长周易的哲学解读。\n\n接下来，你收到的都是关于周易卦象的解释，你需要整理润色，并生成用于大模型训练的内容和格式。\n\n示例输入：\n\n师卦，此卦是异卦相叠，下卦为坎，上卦为坤。“师”指军队。坎为水、为险；坤为地、为顺，喻寓兵于农。兵凶战危，用兵乃圣人不得已而为之，但它可以顺利无阻碍地解决矛盾，因为顺乎形势，师出有名，故能化凶为吉。占得此卦，对于军事上率师出征非常有利，必无灾祸。师卦是天马出群之卦，以寡伏众之象。\n师卦位于讼卦之后，《序卦》之中这样解释道：“讼必有众起，故受之以师。师者，众也。”争讼的人越来越多，以致形成了军队。\n\n期待结果：\n\ncontent:\"师卦\"\nsummary:\"在周易中，师卦是一个极具深意的卦象，它由两个异卦相叠组成：下卦坎（水）和上卦坤（地）。这一卦象代表“师”，即军队，寓意着兵力和农力的结合。在这里，坎卦象征着水和险难，而坤卦象征着地和顺从，暗示着通过将军事力量安置于民间，可以在必要时顺利调动。\n\n师卦的核心哲学是：虽然兵力代表着危险和战争，但其使用应当是圣人不得已而为之的最后手段。在正确的情况下，军事力量可以顺应形势，将危险转化为吉祥。因此，在军事策略上，此卦象征着出征将会顺利，无灾祸。\n\n师卦紧随讼卦（争讼卦），在《序卦》中解释为“讼必有众起，故受之以师”。这意味着争端激化至众多人群的参与，形成了类似军队的集体力量。\""
    },
    {
      "role": "user",
      "content": "蒙卦是教育启蒙的智慧，艮为山，坎为泉，山下出泉。泉水始流出山，则必将渐汇成江河,正如蒙稚渐启，又山下有险，因为有险停止不前，所以蒙昧不明。事物发展的初期阶段，必然蒙昧，所以教育是当务之急，养学生纯正无邪的品质，是治蒙之道。\n蒙卦，这个卦是异卦相叠，下卦为坎，上卦为艮。艮是山的形象，喻止；坎是水的形象，喻险。卦形为山下有险，仍不停止前进，是为蒙昧，故称蒙卦。但因把握时机，行动切合时宜;因此，具有启蒙和通达的卦象。\n《蒙》卦是《屯》卦这个始生卦之后的第二卦。《序卦》中说：“物生必蒙，故受之以蒙。蒙者，蒙也，特之稚也。”物之幼稚阶段，有如蒙昧未开的状态，在人则是指童蒙。\n《象》中这样解释蒙卦：山下出泉，蒙；君子以果行育德。"
    },
    {
      "role": "assistant",
      "content": "content:\"蒙卦\"\nsummary:\"在周易中，蒙卦象征着教育启蒙和智慧的初期阶段，由两个异卦相叠组成：下卦坎（水）和上卦艮（山）。坎象征水，艮象征山，代表了山下有水源，水流出山。这预示着在事物发展的起初阶段，人们会陷入蒙昧状态，因此教育成为当务之急。只有培养纯正无邪的品质，才能走上通达之路，如同泉水汇成江河。\n\n蒙卦的核心哲学是：事物发展的初期阶段必然处于蒙昧状态，但如果能把握时机，行动切合时宜，就能启蒙通达。蒙卦紧随始生卦《屯》之后，《序卦》中解释道：“物生必蒙，故受之以蒙。蒙者，蒙也，特之稚也。”这说明物在幼稚阶段都会经历蒙昧状态，找它蒙即是稚嫩。\n\n《象》中解释说：山下出泉，蒙；君子以果行育德，意味着像泉水从山下流出一样，启蒙教育有助于培育美德。\""
    },
    {
      "role": "user",
      "content": "需卦，本卦是异卦相叠，上卦为坎，下卦为乾。乾卦象征天空辽阔，坎卦象征乌云密布。雨水之于传统农业社会而言，是最大的需求，因此用这个意象来表现。古人引申为雨将下，万物皆待，所以叫需。\n需，古体字结构是“雨上天下”，从雨而声。如苍天下雨，滋养万物及人。从人的角度看，天下雨，则不易出行耕作，因此在家喝酒吃肉、静待天时。所以，这一卦的基本象征就是等待、不进，还有饮食之义。\n \n需卦位于蒙卦之后，《序卦》之中这样解释道：“物稚不可不养也，故受之以需。需者，饮食之道也。”有所需要，也是有所等待。\n《象》曰：云上于天，需;君子以饮食宴乐。\n《象》中这段话的意思是说：需卦的卦象是乾(天)下坎(水)上，为水在天上之表象。水汽聚集天上成为云层，密云満天，但还没有下雨，需要等待;君子在这个时候需要吃喝，饮酒作乐，即在等待的时候积蓄力量。\n需卦象征等待，启示人们守正待机的道理，属于中上卦。《象》这样评断此卦：明珠土埋日久深，无光无亮到如今，忽然大风吹土去，自然显露有重新。\n"
    },
    {
      "role": "assistant",
      "content": "content:\"需卦\"\nsummary:\"在周易中，需卦是一个富有深意的卦象，由两个异卦相叠组成：下卦乾（天）和上卦坎（水）。乾象征广阔的天空，而坎象征乌云密布，暗示着迫切需要雨水的意象。古人将雨水视为万物生长的必需，因此命名为“需”。需卦的基本象征是等待和饮食之道。\n\n需卦位于蒙卦之后，《序卦》中解释为“物稚不可不养也，故受之以需。需者，饮食之道也。”说明物在幼稚状态需要得到滋养，因此受到需卦的启示。《象》中描述：云上于天，需；君子以饮食宴乐。意味着天空乌云密布，需要等待雨水，而君子则在等待的过程中积蓄力量，享受饮食和欢乐。\n\n需卦的核心哲学是：等待，启示着守正待机的道理。它属于中上卦，象征着埋藏已久的明珠，经过大风吹去尘埃后，重新显露光芒。\""
    }
  ],
  temperature=1,
  max_tokens=4095,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)
print(response)
# Out:
# ChatCompletion(id='chatcmpl-8xSueUoulxLfYC3CKXnXRE6WlE0zR', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='生成文本已经发送给你了，希望你满意。', role='assistant', function_call=None, tool_calls=None))], created=1709183184, model='gpt-3.5-turbo-1106', object='chat.completion', system_fingerprint='fp_b3e55cb931', usage=CompletionUsage(completion_tokens=19, prompt_tokens=2472, total_tokens=2491))

# %% [markdown]
# ## 使用 LangChain 构造训练数据

# %%
# 导入所需模块
from langchain.chat_models import ChatOpenAI  # 导入 LangChain 提供的 ChatOpenAI 模型
from langchain.schema import HumanMessage, SystemMessage  # 导入 LangChain 中的人类消息和系统消息的模式
from langchain.prompts.chat import (  # 导入 LangChain 提供的用于对话的模板
    ChatPromptTemplate,  # 对话模板
    HumanMessagePromptTemplate,  # 人类消息的模板
    SystemMessagePromptTemplate,  # 系统消息的模板
)

# 创建一个 ChatOpenAI 实例，用于与 GPT-3.5 模型进行对话
chat = ChatOpenAI(
    model="gpt-3.5-turbo-1106",  # 使用的模型名称
    temperature=1,  # 温度参数，控制生成文本的多样性
    max_tokens=4095,  # 生成文本的最大长度
    top_p=1,  # 采样概率的一个参数，控制生成文本的多样性
    frequency_penalty=0,  # 频率惩罚参数，用于抑制重复的单词
    presence_penalty=0  # 存在惩罚参数，用于抑制输出中包含有选择性词汇
)
# Out:
# WARNING! top_p is not default parameter.
#                     top_p was transferred to model_kwargs.
#                     Please confirm that top_p is what you intended.
# WARNING! frequency_penalty is not default parameter.
#                     frequency_penalty was transferred to model_kwargs.
#                     Please confirm that frequency_penalty is what you intended.
# WARNING! presence_penalty is not default parameter.
#                     presence_penalty was transferred to model_kwargs.
#                     Please confirm that presence_penalty is what you intended.

# %%
system_content = """
你是中国古典哲学大师，尤其擅长周易的哲学解读。

接下来，你收到的都是关于周易卦象的解释，你需要整理润色，并生成用于大模型训练的内容和格式。

示例输入：

师卦，此卦是异卦相叠，下卦为坎，上卦为坤。“师”指军队。坎为水、为险；坤为地、为顺，喻寓兵于农。兵凶战危，用兵乃圣人不得已而为之，但它可以顺利无阻碍地解决矛盾，因为顺乎形势，师出有名，故能化凶为吉。占得此卦，对于军事上率师出征非常有利，必无灾祸。师卦是天马出群之卦，以寡伏众之象。
师卦位于讼卦之后，《序卦》之中这样解释道：“讼必有众起，故受之以师。师者，众也。”争讼的人越来越多，以致形成了军队。

期待结果：

content:"师卦"
summary:"在周易中，师卦是一个极具深意的卦象，它由两个异卦相叠组成：下卦坎（水）和上卦坤（地）。这一卦象代表“师”，即军队，寓意着兵力和农力的结合。在这里，坎卦象征着水和险难，而坤卦象征着地和顺从，暗示着通过将军事力量安置于民间，可以在必要时顺利调动。

师卦的核心哲学是：虽然兵力代表着危险和战争，但其使用应当是圣人不得已而为之的最后手段。在正确的情况下，军事力量可以顺应形势，将危险转化为吉祥。因此，在军事策略上，此卦象征着出征将会顺利，无灾祸。

师卦紧随讼卦（争讼卦），在《序卦》中解释为“讼必有众起，故受之以师”。这意味着争端激化至众多人群的参与，形成了类似军队的集体力量。"
"""

# %%
# 原始数据
raw_content = "蒙卦是教育启蒙的智慧，艮为山，坎为泉，山下出泉。泉水始流出山，则必将渐汇成江河,正如蒙稚渐启，又山下有险，因为有险停止不前，所以蒙昧不明。事物发展的初期阶段，必然蒙昧，所以教育是当务之急，养学生纯正无邪的品质，是治蒙之道。\n蒙卦，这个卦是异卦相叠，下卦为坎，上卦为艮。艮是山的形象，喻止；坎是水的形象，喻险。卦形为山下有险，仍不停止前进，是为蒙昧，故称蒙卦。但因把握时机，行动切合时宜;因此，具有启蒙和通达的卦象。\n《蒙》卦是《屯》卦这个始生卦之后的第二卦。《序卦》中说：“物生必蒙，故受之以蒙。蒙者，蒙也，特之稚也。”物之幼稚阶段，有如蒙昧未开的状态，在人则是指童蒙。\n《象》中这样解释蒙卦：山下出泉，蒙；君子以果行育德。"

# %%
messages = [
    SystemMessage(
        content=system_content
    ),
    HumanMessage(
        content=raw_content
    ),
]

# %%
ai_message = chat(messages)

# %% [markdown]
# ### 解析 OpenAI GPT 生成的训练数据

# %%
ai_message.content
# Out:
# '```json\n{\n  "content": "蒙卦",\n  "summary": "在周易中，蒙卦是异卦相叠的卦象，下卦为坎（水），上卦为艮（山）。坎象征着水的险难，而艮象征着山的停止，卦形则是山下有险仍继续前进，代表了蒙昧和幼稚的状态。然而，卦象也指出了把握时机、行动切合时宜的特质，具有启蒙和通达的含义。",\n  "interpretation": "蒙卦代表了事物发展的初期阶段，这个阶段必然是蒙昧而幼稚的。因此，教育对于启蒙是当务之急，教导学生培养纯正无邪的品质，是治蒙之道。占得此卦时，需要警惕山下的险难，停止不前，以避免蒙昧不明。同时，也需要把握时机，行动切合时宜，以实现启蒙和通达的目标。",\n  "sequence": "蒙卦位于《屯卦》之后，《序卦》中指出：“物生必蒙，故受之以蒙。蒙者，蒙也，特之稚也。”说明物之幼稚阶段有如蒙昧未开的状态，人指的是童蒙。《象》中解释蒙卦是指山下出泉，代表了蒙昧的状态；而君子则以果行育德，即教育之重要性。"\n}\n```\n'

# %%
# 从 ai_message 中获取消息内容
text = ai_message.content

# 找到 content 和 summary 在字符串中的位置
content_start = text.find('content:"') + len('content:"')  # 找到 content 的起始位置
content_end = text.find('"\nsummary:')  # 找到 content 的结束位置
summary_start = text.find('summary:"') + len('summary:"')  # 找到 summary 的起始位置
summary_end = text.rfind('"')  # 找到 summary 的结束位置

# 提取并存储 content 和 summary
content = text[content_start:content_end].strip()  # 提取并去除首尾空格的 content
summary = text[summary_start:summary_end].strip()  # 提取并去除首尾空格的 summary

# 打印 content 和 summary
print("Content:", content)
print("Summary:", summary)
# Out:
# Content: {
#   "content": "蒙卦",
#   "summary": "在周易中，蒙卦是异卦相叠的卦象，下卦为坎（水），上卦为艮（山）。坎象征着水的险难，而艮象征着山的停止，卦形则是山下有险仍继续前进，代表了蒙昧和幼稚的状态。然而，卦象也指出了把握时机、行动切合时宜的特质，具有启蒙和通达的含义。",
#   "interpretation": "蒙卦代表了事物发展的初期阶段，这个阶段必然是蒙昧而幼稚的。因此，教育对于启蒙是当务之急，教导学生培养纯正无邪的品质，是治蒙之道。占得此卦时，需要警惕山下的险难，停止不前，以避免蒙昧不明。同时，也需要把握时机，行动切合时宜，以实现启蒙和通达的目标。",
#   "sequence": "蒙卦位于《屯卦》之后，《序卦》中指出：“物生必蒙，故受之以蒙。蒙者，蒙也，特之稚也。”说明物之幼稚阶段有如蒙昧未开的状态，人指的是童蒙。《象》中解释蒙卦是指山下出泉，代表了蒙昧的状态；而君子则以果行育德，即教育之重要性。"
# }
# ```
# Summary: {
#   "content": "蒙卦",
#   "summary": "在周易中，蒙卦是异卦相叠的卦象，下卦为坎（水），上卦为艮（山）。坎象征着水的险难，而艮象征着山的停止，卦形则是山下有险仍继续前进，代表了蒙昧和幼稚的状态。然而，卦象也指出了把握时机、行动切合时宜的特质，具有启蒙和通达的含义。",
#   "interpretation": "蒙卦代表了事物发展的初期阶段，这个阶段必然是蒙昧而幼稚的。因此，教育对于启蒙是当务之急，教导学生培养纯正无邪的品质，是治蒙之道。占得此卦时，需要警惕山下的险难，停止不前，以避免蒙昧不明。同时，也需要把握时机，行动切合时宜，以实现启蒙和通达的目标。",
#   "sequence": "蒙卦位于《屯卦》之后，《序卦》中指出：“物生必蒙，故受之以蒙。蒙者，蒙也，特之稚也。”说明物之幼稚阶段有如蒙昧未开的状态，人指的是童蒙。《象》中解释蒙卦是指山下出泉，代表了蒙昧的状态；而君子则以果行育德，即教育之重要性。

# %% [markdown]
# ### 持久化存储训练数据集文件

# %%
import csv

# 如果没有GPT API，可以使用预定义的变量
# content = "蒙卦"
# summary = "在周易中，师卦是一个极具深意的卦象，它由两个异卦相叠组成：下卦坎（水）和上卦坤（地）。这一卦象代表“师”，即军队，寓意着兵力和农力的结合。在这里，坎卦象征着水和险难，而坤卦象征着地和顺从，暗示着通过将军事力量安置于民间，可以在必要时顺利调动。师卦的核心哲学是：虽然兵力代表着危险和战争，但其使用应当是圣人不得已而为之的最后手段。在正确的情况下，军事力量可以顺应形势，将危险转化为吉祥。因此，在军事策略上，此卦象征着出征将会顺利，无灾祸。师卦紧随讼卦（争讼卦），在《序卦》中解释为“讼必有众起，故受之以师”。这意味着争端激化至众多人群的参与，形成了类似军队的集体力量。"

# 新建CSV文件并写入数据
with open('test_dataset.csv', mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    # 写入标题行
    writer.writerow(['content', 'summary'])
    # 写入数据行
    writer.writerow([content, summary])

# %% [markdown]
# ### 数据增强：构造多样化的提问方式

# %%
def generate_question_summary_pairs(content, summary):
    """
    生成20对提问和总结的配对。

    :param content: 内容（例如：“蒙卦”）。
    :param summary: 内容的总结。
    :return: 包含20对提问和总结的列表。
    """
    # 20种提问模板
    question_templates = [
        "{}代表什么？",
        "周易中的{}含义是什么？",
        "请解释一下{}。",
        "{}在周易中是什么象征？",
        "周易{}的深层含义是什么？",
        "{}和教育启蒙有什么联系？",
        "周易的{}讲述了什么？",
        "{}是怎样的一个卦象？",
        "{}在周易中怎样表达教育的概念？",
        "{}的基本意义是什么？",
        "周易中{}的解释是什么？",
        "{}在周易中代表了哪些方面？",
        "{}涉及哪些哲学思想？",
        "周易中{}的象征意义是什么？",
        "{}的主要讲述内容是什么？",
        "周易{}的核心思想是什么？",
        "{}和启蒙教育之间有何联系？",
        "在周易中，{}象征着什么？",
        "请描述{}的含义。",
        "{}在周易哲学中扮演什么角色？"
    ]

    # 使用content填充提问模板
    questions = [template.format(content) for template in question_templates]

    # 创建提问和总结的配对
    question_summary_pairs = [(question, summary) for question in questions]

    return question_summary_pairs

# %%
import csv

# 如果没有GPT API，可以使用预定义的变量
# content = "蒙卦"
# summary = "在周易中，师卦是一个极具深意的卦象，它由两个异卦相叠组成：下卦坎（水）和上卦坤（地）。这一卦象代表“师”，即军队，寓意着兵力和农力的结合。在这里，坎卦象征着水和险难，而坤卦象征着地和顺从，暗示着通过将军事力量安置于民间，可以在必要时顺利调动。师卦的核心哲学是：虽然兵力代表着危险和战争，但其使用应当是圣人不得已而为之的最后手段。在正确的情况下，军事力量可以顺应形势，将危险转化为吉祥。因此，在军事策略上，此卦象征着出征将会顺利，无灾祸。师卦紧随讼卦（争讼卦），在《序卦》中解释为“讼必有众起，故受之以师”。这意味着争端激化至众多人群的参与，形成了类似军队的集体力量。"
pairs = generate_question_summary_pairs(content, summary)

# 将结果写入CSV文件
with open('test_dataset.csv', mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(['content', 'summary'])
    for pair in pairs:
        writer.writerow(pair)

# %% [markdown]
# ### 自动化批量生成训练数据流水线

# %% [markdown]
# 原始数据来源：https://www.zhouyi.cc/zhouyi/yijing64/4103.html

# %%
# 初始化一个空列表用于存储原始内容数据
raw_content_data = []

# 读取文件并分割数据样例
with open('data/raw_data.txt', 'r', encoding='utf-8') as file:
    content = file.read()
    # 使用连续的换行符('\n\n')作为分隔符来分割文本
    data_samples = content.split('\n\n')

    # 遍历分割后的数据样例并添加到列表中
    for sample in data_samples:
        # 移除每个样例中的额外空白字符（如果有的话）
        cleaned_sample = sample.strip()
        # 仅添加非空样例
        if cleaned_sample:
            raw_content_data.append(cleaned_sample)

# %%
# 输出结果以验证
for i, sample in enumerate(raw_content_data[:5]):  # 打印前5个样例以检查
    print(f"样例 {i+1}:")
    print(sample)
    print("------")
# Out:
# 样例 1:
# 蒙卦原文
# 蒙。亨。匪我求童蒙，童蒙求我。初筮告，再三渎，渎则不告。利贞。
# 象曰：山下出泉，蒙。君子以果行育德。
# 白话文解释
# 蒙卦：通泰。不是我有求于幼稚愚昧的人，而是幼稚愚昧的人有求于我。第一次占筮，神灵告诉了他。轻慢不敬的再三占筮，轻慢不敬的占筮，神灵就不会告诉他。但还是吉利的卜问。
# 《象辞》说：上卦为艮，象征山；下卦为坎，象征泉。山下有泉，泉水喷涌而出，这是蒙卦的卦象。君子观此卦象，取法于一往无前的山泉，从而以果敢坚毅的行动来培养自身的品德。
# 《断易天机》解
# 蒙卦艮上坎下，为离宫四世卦。蒙即蒙昧，主回还往复，疑惑不前，多忧愁过失，乃是凶卦。
# 北宋易学家邵雍解
# 智慧未开，蒙昧闭塞；犹豫不决，缺乏果断。
# 得此卦者，智慧犹如童蒙，不辨是非，迷失方向；若能顺贤师良友之教，启其聪明则亨通。
# 台湾国学大儒傅佩荣解
# 时运：蓄积德行，出而用世。
# 财运：矿山生意，果决则吉。
# 家宅：君子居吉；婚姻之始。
# 身体：驱去邪热，可保平安。
# 传统解卦
# 这个卦是异卦（下坎上艮）相叠，艮是山的形象，喻止；坎是水的形象，喻险。卦形为山下有险，仍不停止前进，是为蒙昧，故称蒙卦。但因把握时机，行动切合时宜，因此，具有启蒙和通达的卦象。
# 大象：蒙者，昏而无所见也，故宜「启蒙」。
# 运势：初时迷惑不知方向，须忍耐待机而动，凡事多听取别人意见，则运可通。
# 事业：事业开始，混乱无序，危机四伏，以勇敢坚毅的行动可以扭转局面。然而必须接受严格教育，培养这种奋发图强的精神。务必脚踏实地，最忌好高骛远，否则会陷入孤立无援的境地。
# 经商：务必小心谨慎，不得急功近利，尤其应树立高尚的商业道德，以良好的信誉提高竞争力而取胜。
# 求名：必须接受良好的基础教育，陶冶情操。且动机纯正，可以达到目的。
# 婚恋：注意考察对方品德，不可以金钱为诱铒。夫妻需相互宽容、理解。
# 决策：有时会陷入迷惘困顿的境地，加上胆小、不果断，往往误事。如能接受长辈的教诲，甚至严酷的考验，抛弃疑惧的心理，等待适当时机，必然一帆风顺。
# ------
# 样例 2:
# 屯卦原文
# 屯。元，亨，利，贞。勿用，有攸往，利建侯。
# 象曰：云，雷，屯；君子以经纶。
# 白话文解释
# 屯卦。大吉大利，吉利的占卜。不利于出门。有利于建国封侯。
# 《象辞》说：屯的上卦为坎，坎为云，下卦为震，震为雷。云行于上，雷动于下，是屯卦的卦象。君子观此卦象，取法于云雷，用云的恩泽，雷的威严来治理国事。
# 《断易天机》解
# 屯卦坎上震下，为坎宫二世卦。屯说明有困难，又象征动而逢险境，需刚毅果敢方为吉。
# 北宋易学家邵雍解
# 万物始生，开始困难；先劳后逸，苦尽甘来。
# 得此卦者，身处困境，宜守不宜进，须多加辛苦努力，排除困难，方可通达，有初难后解之象。
# 台湾国学大儒傅佩荣解
# 时运：宜守不宜进。
# 财运：创业维艰。
# 家宅：修缮住宅；初婚不和。
# 身体：保存元气。
# 传统解卦
# 这个卦是异卦（下震上坎）相叠，震为雷，喻动；坎为雨，喻险。雷雨交加，险象丛生，环境恶劣。“屯”原指植物萌生大地，万物始生，充满艰难险阻，然而顺时应运，必欣欣向荣。
# 大象：屯者难也，万事欲进而不得进。
# 运势：身处困境，步步为营，有初难后解之意。
# 事业：起初多有不利，要知难而进，小心翼翼，勇往直前，灵活机动，可望获得大的成功，时机到来时一定要抓住，却也不得操之太急，且仍有困难，务必有他人相助，故平时应多施恩惠。
# 经商：创业初期步履艰难，多有挫折。坚定信念最重要，不要为表面现象所迷惑，应积极进取，行动果断，打开出路。若仍无法摆脱困境，则应退守保全，等待机会，再展宏图。
# 求名：积极争取，主动追求，可以成功。
# 婚恋：好事多磨，忠贞纯洁，大胆追求，能够成功，婚姻美满。
# 决策：初始困难，但若具有坚忍不拔的毅力和锲而不舍的奋斗精神，前途不可估量，但往往不为他人理解而陷于孤独苦闷，事业会因此处于困难状态，需要得到贤德之人的帮助才能摆脱。如能以乐观主义精神处世，能取得成就。
# ------
# 样例 3:
# 需卦原文
# 需。有孚，光亨，贞吉。利涉大川。
# 象曰：云上于天，需；君子以饮食宴乐。
# 白话文解释
# 需卦：抓到俘虏。大吉大利，吉利的卜问。有利于涉水渡河。
# 《象辞》说：需的上卦为坎，表示云；下卦为乾，表示天。云浮聚于天上，待时降雨是需卦的卦象。君子观此卦象，可以宴饮安乐，待时而动。
# 《断易天机》解
# 需卦坎上乾下，为坤宫游魂卦。需为踌躇、期待，虽然刚强，但前面有险阻，应当等待，涉大川则利。
# 北宋易学家邵雍解
# 坎陷当前，遇阻不进；大器晚成，收成在后。
# 得此卦者，时机尚未成熟，需要耐心等待，急进反会见凶。
# 台湾国学大儒傅佩荣解
# 时运：时机尚未成熟，耐心等待。
# 财运：资本未集，无法开张。
# 家宅：平安是福。
# 身体：调节饮食，健康有望。
# 传统解卦
# 这个卦是异卦（下乾上坎）相叠，下卦是乾，刚健之意；上卦是坎，险陷之意。以刚逢险，宜稳健之妥，不可冒失行动，观时待变，所往一定成功。
# 大象：云登天上而未雨，不能急进，等待时机之象。
# 运势：智者必须待时而行，急进反见凶险。
# 事业：关键在于审时度势，耐心等待，事成于安祥，切勿冒险，欲速不达。自己要充满自信，临危不惧，坚守中正，必可化险为夷。情况有利时，仍得居安思危。
# 经商：行动之初，情况困难，必须以极大的耐心，创造条件和机会，行事光明磊落，观时待变，实现愿望。事情接近成功时，更应小心谨慎，切莫功亏一篑。
# 求名：时机尚不成熟，应耐心等待。这时应坚定信念，不为闲言流语所动摇，努力丰富自己，再求助可靠的人便可成功。
# 婚恋：慎重，切不可草率行事，逐渐培养感情，以诚实、热情相待，会发生变故，仍可以有良好的结局。双方都应懂得以柔克刚的道理。
# 决策：前途光明，有雄心大志，且可实现。为此需要积蓄实力，等待时机，大器晚成。本人具有坚强的意志，冷静的头脑。前进途中会遇到困难和险阻，必须十分谨慎，坦然对待小人的中伤，在灾祸在面前能镇静自若。不轻举妄动，冷静选择方向。为人谦和、坦率，多有他人相助，促使事业成功。当时机成熟后，必然一帆风顺。
# ------
# 样例 4:
# 讼卦原文
# 讼。有孚，窒惕，中吉，终凶。利见大人，不利涉大川。
# 象曰：天与水违行，讼。君子以做事谋始。
# 白话文解释
# 讼卦：虽有利可图(获得俘虏)，但要警惕戒惧。其事中间吉利，后来凶险。占筮得此爻，有利于会见贵族王公，不利于涉水渡河。
# 《象辞》说：上卦为乾，乾为天；下卦为坎，坎为水，天水隔绝，流向相背，事理乖舛，这是讼卦的卦象。君子观此卦象，以杜绝争讼为意，从而在谋事之初必须慎之又慎。
# 《断易天机》解
# 讼卦乾上坎下，为离宫游魂卦。上乾为刚，下坎为险，一方刚强，一方阴险，必然产生争论，因此多有不吉。
# 北宋易学家邵雍解
# 天高水深，达远不亲；慎谋退守，敬畏无凶。
# 得此卦者，身心不安，事多不顺，与他人多争诉之事，宜修身养性，谨慎处事。
# 台湾国学大儒傅佩荣解
# 时运：功名受阻，不宜树敌。
# 财运：开始谨慎，终可获利。
# 家宅：君子必求淑女。
# 身体：预防胜于治疗。
# 传统解卦
# 这个卦是异卦（下坎上乾）相叠。同需卦相反，互为“综卦”。乾为刚健，坎为险陷。刚与险，健与险，彼此反对，定生争讼。争讼非善事，务必慎重戒惧。
# 大象：乾天升于上，坎水降于下，相背而行而起讼。
# 运势：事与愿违，凡事不顺，小人加害，宜防陷阱。
# 事业：起初顺利，有利可图，继而受挫，务必警惕，慎之又慎，不得固执已见，极力避免介入诉讼纠纷的争执之中。与其这样，不如退而让人，求得化解，安于正理，可免除意外之灾。陷入争讼，即使获胜，最后还得失去，得不偿失。
# 经商：和气生财，吃亏是福，切勿追求不义之财。商业谈判应坚持公正、公平、互利的原则，尽量避免发生冲突。这样便会有好结果。
# 求名：不利。自己尚缺乏竞争实力，应坚守纯正，隐忍自励，自强自勉，切莫逞强。依靠有地位的人的帮助，及早渡过难关。
# 婚恋：虽不尽人意，倒也般配，彼此理解，未尝不可。双方应以温和的方式处理生活。
# 决策：争强好胜，不安于现状，为改变命运和超越他人而奋斗。头脑聪颖，反应敏捷，有贵人相助。但缺乏持之以恒的毅力，容易露出锋芒，得罪他人，带来诉讼之灾。宜承认现实，顺其自然，知足，适可而止。接受教训，引以为戒，可功成名就。
# ------
# 样例 5:
# 师卦原文
# 师。贞，丈人吉，无咎。
# 象曰：地中有水，师。君子以容民畜众。
# 白话文解释
# 师卦：占问总指挥的军情，没有灾祸。
# 《象辞》说：下卦为坎，坎为水；上卦为坤，坤为地，像“地中有水”，这是师卦的卦象。君子观此卦象，取法于容纳江河的大地，收容和畜养大众。
# 《断易天机》解
# 师卦坤上坎下，为坎宫归魂卦。师即兵众，只有选择德高望重的长者来统率军队，才能吉祥无咎。
# 北宋易学家邵雍解
# 忧劳动众，变化无穷；公正无私，排除万难。
# 得此卦者，困难重重，忧心劳众，宜包容别人，艰苦努力，摒除一切困难。
# 台湾国学大儒傅佩荣解
# 时运：包容别人，修行待时。
# 财运：有财有库，善自珍惜。
# 家宅：旧亲联姻，可喜可贺。
# 身体：腹胀之症，调气无忧。
# 传统解卦
# 这个卦是异卦（下坎上坤）相叠。“师”指军队。坎为水、为险；坤为地、为顺，喻寓兵于农。兵凶战危，用兵乃圣人不得已而为之，但它可以顺利无阻碍地解决矛盾，因为顺乎形势，师出有名，故能化凶为吉。
# 大象：养兵聚众，出师攻伐之象，彼此有伤，难得安宁。
# 运势：困难重重，凡事以正规行事，忌独断独行、投机取巧，提防潜在敌人。
# 事业：阻力很大，困难很多，处于激烈的竞争状态，要与他人密切合作，谨小慎微，行为果断，切忌盲目妄动，适度即可，注意保全自己。机动灵活，严于律已。从容沉着对付一切，必能成功。
# 经商：已有一定的积蓄，可以从事大的营销活动，但必卷入激烈商战，以刚毅顽强的精神和高尚的商业道德，辅以灵活的方法，勿贪图小利，勿掉以轻心，加强与他人的沟通，必可摆脱困境，化险为夷。
# 求名：具备很好的条件，但须有正确的引导，务必严格要求自己，克服不利因素的干扰，经过扎实努力，必可名利双全。
# 婚恋：慎重、专注，否则会陷入“三角”纠纷。痴情追求可以达到目的。
# 决策：天资聪颖，性格灵活，具有坚强的意志，对事业执着追求，迎难而进。可成就大事业。喜竞争，善争辩，富有冒险精神，不免带来麻烦，务老成持重，不贪功，以中正为要。
# ------

# %% [markdown]
# ### 将以上的所有模块，整合到一起，自动化生成数据

# %%
from langchain.chat_models import ChatOpenAI
from langchain.schema import HumanMessage, SystemMessage
from langchain.prompts.chat import (
    ChatPromptTemplate,
    HumanMessagePromptTemplate,
    SystemMessagePromptTemplate,
)

# 初始化LangChain的GPT-3.5调用
chat = ChatOpenAI(model="gpt-3.5-turbo-1106",
                  temperature=1,
                  max_tokens=4095,
                  top_p=1,
                  frequency_penalty=0,
                  presence_penalty=0)

def gen_data(raw_content):
    """
    使用LangChain GPT-3.5调用处理单个数据样例。

    :param raw_content: 原始数据样例。
    :return: GPT-3.5模型生成的内容。
    """
    # 系统消息定义背景和任务
    system_message = SystemMessage(
        content="""
        你是中国古典哲学大师，尤其擅长周易的哲学解读。

        接下来，你收到的都是关于周易卦象的解释，你需要整理润色，并生成用于大模型训练的内容和格式。

        示例输入：

        师卦，此卦是异卦相叠，下卦为坎，上卦为坤。“师”指军队。坎为水、为险；坤为地、为顺，喻寓兵于农。兵凶战危，用兵乃圣人不得已而为之，但它可以顺利无阻碍地解决矛盾，因为顺乎形势，师出有名，故能化凶为吉。占得此卦，对于军事上率师出征非常有利，必无灾祸。师卦是天马出群之卦，以寡伏众之象。
        师卦位于讼卦之后，《序卦》之中这样解释道：“讼必有众起，故受之以师。师者，众也。”争讼的人越来越多，以致形成了军队。

        期待结果：

        content:"师卦"
        summary:"在周易中，师卦是一个极具深意的卦象，它由两个异卦相叠组成：下卦坎（水）和上卦坤（地）。这一卦象代表“师”，即军队，寓意着兵力和农力的结合。在这里，坎卦象征着水和险难，而坤卦象征着地和顺从，暗示着通过将军事力量安置于民间，可以在必要时顺利调动。

        师卦的核心哲学是：虽然兵力代表着危险和战争，但其使用应当是圣人不得已而为之的最后手段。在正确的情况下，军事力量可以顺应形势，将危险转化为吉祥。因此，在军事策略上，此卦象征着出征将会顺利，无灾祸。

        师卦紧随讼卦（争讼卦），在《序卦》中解释为“讼必有众起，故受之以师”。这意味着争端激化至众多人群的参与，形成了类似军队的集体力量。"
        """
    )

    # 人类消息包含原始数据样例
    human_message = HumanMessage(
        content=raw_content
    )

    # 构建消息列表并进行模型调用
    messages = [system_message, human_message]
    ai_message = chat(messages)

    return ai_message.content
# Out:
# WARNING! top_p is not default parameter.
#                     top_p was transferred to model_kwargs.
#                     Please confirm that top_p is what you intended.
# WARNING! frequency_penalty is not default parameter.
#                     frequency_penalty was transferred to model_kwargs.
#                     Please confirm that frequency_penalty is what you intended.
# WARNING! presence_penalty is not default parameter.
#                     presence_penalty was transferred to model_kwargs.
#                     Please confirm that presence_penalty is what you intended.

# %%
# 示例调用（使用 raw_data.txt 中解析的数据样例）
generated_content = gen_data(raw_content_data[0])
print(generated_content)
# Out:
# content:"蒙卦"
# summary:"在周易中，蒙卦是一个充满深意的卦象。它由下卦坎（水）和上卦艮（山）组成，在象辞中描述了山下有泉的情景，寓意着启蒙和通达。这一卦象代表着开始时的迷惑和犹豫，需要等待时机，倾听他人意见，方可通达。
#
# 蒙卦的核心哲学是：在开始阶段面临混乱和危机，需要勇敢和坚毅的行动来扭转局面。然而，必须接受严格的教育，培养奋发进取的精神，并且务必踏实地行事，避免好高鹜远。也必须具备启蒙和通达的心态。
#
# 根据易经解析，蒙卦暗示着迷惑不知方向，需要忍耐和倾听别人的意见，才能找到时机并改变运势。在事业、经商、求名、婚恋和决策等方面，都需要通过接受教育和顺势而为来获得成功。"

# %%
def dataset_parser(ai_message_content):
    """
    解析由gen_data函数生成的ai_message.content，提取content和summary。

    :param ai_message_content: gen_data函数返回的文本。
    :return: 提取的content和summary。
    """
    # 分割字符串来找到content和summary的位置
    content_start = ai_message_content.find('content:"') + len('content:"')
    content_end = ai_message_content.find('"\nsummary:')
    summary_start = ai_message_content.find('summary:"') + len('summary:"')
    summary_end = ai_message_content.rfind('"')

    # 提取并存储content和summary
    content = ai_message_content[content_start:content_end].strip()
    summary = ai_message_content[summary_start:summary_end].strip()

    return content, summary

# %%
# 示例调用（使用假设的gen_data函数返回的文本）
content, summary = dataset_parser(generated_content)
print("Content:", content)
print("Summary:", summary)
# Out:
# Content: 蒙卦
# Summary: 在周易中，蒙卦是一个充满深意的卦象。它由下卦坎（水）和上卦艮（山）组成，在象辞中描述了山下有泉的情景，寓意着启蒙和通达。这一卦象代表着开始时的迷惑和犹豫，需要等待时机，倾听他人意见，方可通达。
#
# 蒙卦的核心哲学是：在开始阶段面临混乱和危机，需要勇敢和坚毅的行动来扭转局面。然而，必须接受严格的教育，培养奋发进取的精神，并且务必踏实地行事，避免好高鹜远。也必须具备启蒙和通达的心态。
#
# 根据易经解析，蒙卦暗示着迷惑不知方向，需要忍耐和倾听别人的意见，才能找到时机并改变运势。在事业、经商、求名、婚恋和决策等方面，都需要通过接受教育和顺势而为来获得成功。

# %%
import csv
import datetime
import os

def main():
    # 确保 data 目录存在
    if not os.path.exists('data'):
        os.makedirs('data')

    # 解析 data/raw_data.txt 得到 raw_content_data 列表
    raw_content_data = []
    with open('data/raw_data.txt', 'r', encoding='utf-8') as file:
        content = file.read()
        data_samples = content.split('\n\n')
        for sample in data_samples:
            cleaned_sample = sample.strip()
            if cleaned_sample:
                raw_content_data.append(cleaned_sample)

    # 创建带有时间戳的CSV文件名
    timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
    filename = f"data/zhouyi_dataset_{timestamp}.csv"

    # 创建CSV文件并写入标题行
    with open(filename, mode='w', newline='', encoding='utf-8') as file:
        writer = csv.writer(file)
        writer.writerow(['content', 'summary'])

        # 循环遍历 raw_content_data 数据样例
        for raw_content in raw_content_data:
            # 调用 gen_data 方法得到 ai_message_content
            ai_message_content = gen_data(raw_content)

            # 解析 ai_message_content 得到 content 和 summary
            content, summary = dataset_parser(ai_message_content)
            
            print("Content:", content)
            print("Summary:", summary)

            # 调用 generate_question_summary_pairs 得到20组 pairs
            pairs = generate_question_summary_pairs(content, summary)

            # 将 pairs 写入 csv 文件
            for pair in pairs:
                writer.writerow(pair)

# %%
# 执行主函数
main()
# Out:
# Content: 蒙卦
# Summary: 在周易中，蒙卦代表着通泰的含义。它由坎卦（水）叠加在艮卦（山）之上而成，象征着在困难险阻的情况下仍然勇往直前，因此被称为蒙昧之卦。然而，如果能够把握时机，按照时势行事，就能够开启智慧、通达机遇。
#
# 蒙卦的核心哲学是：不是我有求于幼稚愚昧的人，而是幼稚愚昧的人有求于我。第一次占筮就能获得神灵的指引，但如果轻慢不敬地再三占筮，神灵就不会告诉他。然而，尽管如此，仍然是一个吉利的卜问。
#
# 蒙卦的形成象征着山下有泉，泉水喷涌而出，暗示着勇敢行动可以培养自身的品德，具有启蒙和通达的特质。
#
# 在运势上，初时迷惑不知方向，需要忍耐待机而动，多听取他人意见，则运势会通达。在事业、经商、求名、婚恋等方面，都需要勇敢坚毅的行动，接受严格的教育和培养，以此来克服困难，取得成功。"
#
# reference:"《断易天机》、北宋易学家邵雍、台湾国学大儒傅佩荣解、传统解卦
# Content: {
# "content": "屯卦",
# "summary": "在周易中，屯卦预示着困难和有始有终的象征。此卦为两个异卦相叠而成：下卦震（雷）上卦坎（水），震卦象征动而坎卦象征险难。整个卦象显示出雷雨交加的恶劣环境，所以屯意味着起始艰难。然而，顺应时势，随时准备行动，必能迎来顺利发展。屯卦的核心是顺应时势，突破困难。",
# "explanation": {
#     "原文": "屯。元，亨，利，贞。勿用，有攸往，利建侯。",
#     "象曰": "云，雷，屯；君子以经纶。",
#     "白话文解释": "屯卦预示着大吉大利，占卜吉利。不利于外出。有利于建国封侯。《象辞》说：屯的上卦为坎，坎为云，下卦为震，震为雷。云行于上，雷动于下，是屯卦的卦象。君子观此卦象，取法于云雷，用云的恩泽，雷的威严来治理国事。",
#     "断易天机": "屯卦坎上震下，为坎宫二世卦。屯说明有困难，又象征动而逢险境，需刚毅果敢方为吉。",
#     "北宋易学家邵雍解": "万物始生，开始困难；先劳后逸，苦尽甘来。得此卦者，身处困境，宜守不宜进，须多加辛苦努力，排除困难，方可通达，有初难后解之象。",
#     "台湾国学大儒傅佩荣解": {
#       "时运": "宜守不宜进。",
#       "财运": "创业维艰。",
#       "家宅": "修缮住宅；初婚不和。",
#       "身体": "保存元气。"
#       },
#     "传统解卦": {
#       "大象": "屯者难也，万事欲进而不得进。"
#       }
#   }
# }
# ``
# Summary: {
# "content": "屯卦",
# "summary": "在周易中，屯卦预示着困难和有始有终的象征。此卦为两个异卦相叠而成：下卦震（雷）上卦坎（水），震卦象征动而坎卦象征险难。整个卦象显示出雷雨交加的恶劣环境，所以屯意味着起始艰难。然而，顺应时势，随时准备行动，必能迎来顺利发展。屯卦的核心是顺应时势，突破困难。",
# "explanation": {
#     "原文": "屯。元，亨，利，贞。勿用，有攸往，利建侯。",
#     "象曰": "云，雷，屯；君子以经纶。",
#     "白话文解释": "屯卦预示着大吉大利，占卜吉利。不利于外出。有利于建国封侯。《象辞》说：屯的上卦为坎，坎为云，下卦为震，震为雷。云行于上，雷动于下，是屯卦的卦象。君子观此卦象，取法于云雷，用云的恩泽，雷的威严来治理国事。",
#     "断易天机": "屯卦坎上震下，为坎宫二世卦。屯说明有困难，又象征动而逢险境，需刚毅果敢方为吉。",
#     "北宋易学家邵雍解": "万物始生，开始困难；先劳后逸，苦尽甘来。得此卦者，身处困境，宜守不宜进，须多加辛苦努力，排除困难，方可通达，有初难后解之象。",
#     "台湾国学大儒傅佩荣解": {
#       "时运": "宜守不宜进。",
#       "财运": "创业维艰。",
#       "家宅": "修缮住宅；初婚不和。",
#       "身体": "保存元气。"
#       },
#     "传统解卦": {
#       "大象": "屯者难也，万事欲进而不得进。
# Content: {
#   "content": "需卦\n有孚，光亨，贞吉。利涉大川。\n云上于天，需；君子以饮食宴乐。\n需卦：抓到俘虏。大吉大利，吉利的卜问。有利于涉水渡河。\n《象辞》说：需的上卦为坎，表示云；下卦为乾，表示天。云浮聚于天上，待时降雨是需卦的卦象。君子观此卦象，可以宴饮安乐，待时而动。\n需卦坎上乾下，为坤宫游魂卦。需为踌躇、期待，虽然刚强，但前面有险阻，应当等待，涉大川则利。\n坎陷当前，遇阻不进；大器晚成，收成在后。\n时运：时机尚未成熟，耐心等待。\n财运：资本未集，无法开张。\n家宅：平安是福。\n身体：调节饮食，健康有望。\n这个卦是异卦（下乾上坎）相叠，下卦是乾，刚健之意；上卦是坎，险陷之意。以刚逢险，宜稳健之妥，不可冒失行动，观时待变，所往一定成功。\n云登天上而未雨，不能急进，等待时机之象。\n智者必须待时而行，急进反见凶险。\n关键在于审时度势，耐心等待，事成于安祥，切勿冒险，欲速不达。自己要充满自信，临危不惧，坚守中正，必可化险为夷。情况有利时，仍得居安思危。\n行动之初，情况困难，必须以极大的耐心，创造条件和机会，行事光明磊落，观时待变，实现愿望。事情接近成功时，更应小心谨慎，切莫功亏一篑。\n时机尚不成熟，应耐心等待。这时应坚定信念，不为闲言流语所动摇，努力丰富自己，再求助可靠的人便可成功。\n慎重，切不可草率行事，逐渐培养感情，以诚实、热情相待，会发生变故，仍可以有良好的结局。双方都应懂得以柔克刚的道理。\n前途光明，有雄心大志，且可实现。为此需要积蓄实力，等待时机，大器晚成。本人具有坚强的意志，冷静的头脑。前进途中会遇到困难和险阻，必须十分谨慎，坦然对待小人的中伤，在灾祸在面前能镇静自若。不轻举妄动，冷静选择方向。为人谦和、坦率，多有他人相助，促使事业成功。当时机成熟后，必然一帆风顺。",
#   "summary": "在周易中，需卦是一个极具深意的卦象。它由上卦乾（天）和下卦坎（水）组成，代表着等待时机的踌躇和期待。虽然刚强，但需要等待，涉水可利。需卦象征着处于待机状态，等待合适的时机才动。坎陷当前，遇阻不进，意味着大器晚成，收成在后。时运尚未成熟，需耐心等待。财运需要资本积累方能开张。家宅宜平安，身体宜调节饮食。对于事业和决策，关键在于审时度势，耐心等待。在行动之初，需充满耐心，创造机会，行事光明磊落，勿贸然行动。在婚恋和求名上，也需要慎重等待适合的时机。前途光明，大器晚成，需要坚定意志，冷静思考，最终将会一帆风顺。",
#   "source": "周易"
# }
# ``
# Summary: {
#   "content": "需卦\n有孚，光亨，贞吉。利涉大川。\n云上于天，需；君子以饮食宴乐。\n需卦：抓到俘虏。大吉大利，吉利的卜问。有利于涉水渡河。\n《象辞》说：需的上卦为坎，表示云；下卦为乾，表示天。云浮聚于天上，待时降雨是需卦的卦象。君子观此卦象，可以宴饮安乐，待时而动。\n需卦坎上乾下，为坤宫游魂卦。需为踌躇、期待，虽然刚强，但前面有险阻，应当等待，涉大川则利。\n坎陷当前，遇阻不进；大器晚成，收成在后。\n时运：时机尚未成熟，耐心等待。\n财运：资本未集，无法开张。\n家宅：平安是福。\n身体：调节饮食，健康有望。\n这个卦是异卦（下乾上坎）相叠，下卦是乾，刚健之意；上卦是坎，险陷之意。以刚逢险，宜稳健之妥，不可冒失行动，观时待变，所往一定成功。\n云登天上而未雨，不能急进，等待时机之象。\n智者必须待时而行，急进反见凶险。\n关键在于审时度势，耐心等待，事成于安祥，切勿冒险，欲速不达。自己要充满自信，临危不惧，坚守中正，必可化险为夷。情况有利时，仍得居安思危。\n行动之初，情况困难，必须以极大的耐心，创造条件和机会，行事光明磊落，观时待变，实现愿望。事情接近成功时，更应小心谨慎，切莫功亏一篑。\n时机尚不成熟，应耐心等待。这时应坚定信念，不为闲言流语所动摇，努力丰富自己，再求助可靠的人便可成功。\n慎重，切不可草率行事，逐渐培养感情，以诚实、热情相待，会发生变故，仍可以有良好的结局。双方都应懂得以柔克刚的道理。\n前途光明，有雄心大志，且可实现。为此需要积蓄实力，等待时机，大器晚成。本人具有坚强的意志，冷静的头脑。前进途中会遇到困难和险阻，必须十分谨慎，坦然对待小人的中伤，在灾祸在面前能镇静自若。不轻举妄动，冷静选择方向。为人谦和、坦率，多有他人相助，促使事业成功。当时机成熟后，必然一帆风顺。",
#   "summary": "在周易中，需卦是一个极具深意的卦象。它由上卦乾（天）和下卦坎（水）组成，代表着等待时机的踌躇和期待。虽然刚强，但需要等待，涉水可利。需卦象征着处于待机状态，等待合适的时机才动。坎陷当前，遇阻不进，意味着大器晚成，收成在后。时运尚未成熟，需耐心等待。财运需要资本积累方能开张。家宅宜平安，身体宜调节饮食。对于事业和决策，关键在于审时度势，耐心等待。在行动之初，需充满耐心，创造机会，行事光明磊落，勿贸然行动。在婚恋和求名上，也需要慎重等待适合的时机。前途光明，大器晚成，需要坚定意志，冷静思考，最终将会一帆风顺。",
#   "source": "周易
# Content: "讼卦
# Summary: "讼卦"
# summary: "讼卦是周易中的一卦，由乾上坎下组成。乾代表天，坎代表水，天与水违背流向相背，代表着争讼之象。在讼卦中，虽有利可图，但需要警惕戒惧，中间吉利，终凶险。占筮得此卦时，有利于会见贵族王公，不利于涉水渡河。君子观此卦象，应杜绝争讼，谨慎谋事之初。讼卦的大象是天高水深，涵义为思慎退守，敬畏无凶。得此卦者，身心不安，事多不顺，宜修身养性，谨慎处事。在运势上，事与愿违，凡事不顺，宜防陷阱。在事业上，起初顺利，后受挫，需警惕谨慎，不得固执已见，力避争讼纠纷。经商上，和气生财，吃亏是福，不追求不义之财。在求名上，应坚守纯正，依靠有地位的人的帮助，及早渡过难关。在婚恋关系中，虽不尽人意，但可互相理解。在决策上，宜承认现实，顺其自然，知足适可而止，接受教训，引以为戒，可功成名就。"
# interpretation: "讼卦是由乾上坎下组成，代表着天与水相背而行的争讼之象。在讼卦中，虽有利可图，但需要警惕戒惧，中间吉利，终凶险。得此卦者，应谨慎处事，杜绝争讼，修身养性，注意防范陷阱。在事业上，应避免固执已见，力避争讼纠纷，在经商上应坚持公正、公平、互利的原则，不追求不义之财。在求名方面，应坚守纯正，依靠有地位的人的帮助，渡过难关。在婚恋关系中，彼此理解，以温和的方式处理生活。在决策上，应承认现实，知足适可而止，接受教训，引以为戒，可功成名就。"
# comment: "整体上需要将文本进行概括和哲学思考的整理，重点突出卦象的涵义和在现实生活中的应用，以及在哲学层面的引申和解读。
# Content: {
#   "content": "师卦：占问总指挥的军情，没有灾祸。《象辞》说：下卦为坎，坎为水；上卦为坤，坤为地，像“地中有水”，这是师卦的卦象。君子观此卦象，取法于容纳江河的大地，收容和畜养大众。师即兵众，只有选择德高望重的长者来统率军队，才能吉祥无咎。忧劳动众，变化无穷；公正无私，排除万难。得此卦者，困难重重，忧心劳众，宜包容别人，艰苦努力，摒除一切困难。时运：包容别人，修行待时。财运：有财有库，善自珍惜。家宅：旧亲联姻，可喜可贺。身体：腹胀之症，调气无忧。这个卦是异卦（下坎上坤）相叠。“师”指军队。坎为水、为险；坤为地、为顺，喻寓兵于农。兵凶战危，用兵乃圣人不得已而为之，但它可以顺利无阻碍地解决矛盾，因为顺乎形势，师出有名，故能化凶为吉。",
#   "summary": "师卦在周易中，是一个极具深意的卦象。由两个异卦相叠组成：下卦坎（水）和上卦坤（地）。这一卦象代表“师”，即军队，寓意兵力和农力的结合。坎为水，代表危险；坤为地，代表顺从。师卦的核心哲学是兵凶战危，但其使用应当是圣人不得已而为之的最后手段。在正确的情况下，军事力量可以顺应形势，将危险转化为吉祥。",
#   "explanation": "师卦位于讼卦之后，《序卦》中解释为“讼必有众起，故受之以师”。这意味着争端激化至众多人群的参与，形成了类似军队的集体力量。在面临困难重重，忧心劳众的情况下，适宜包容别人，艰苦努力，摒除一切困难。在时运上，需要包容别人，修行待机。在财运、家宅、身体方面皆宜以正规行事，保持公正无私，排除万难。",
#   "prediction": "师卦的运势“困难重重”，需要与他人密切合作，谨小慎微，行为果断，避免盲目妄动，保全自己。在事业上，需要机动灵活，严于律已，在商业上要心怀高尚的商业道德，加强与他人的沟通，以此化解困境。在求名、婚恋、决策上则需要慎重、专注，不贪图小利，以中正为要，并且必要时要与他人合作，方可顺利成功。",
#   "scholar": "《断易天机》北宋易学家邵雍；《象辞》傅佩荣解；传统解卦"
# }
# ``
# Summary: {
#   "content": "师卦：占问总指挥的军情，没有灾祸。《象辞》说：下卦为坎，坎为水；上卦为坤，坤为地，像“地中有水”，这是师卦的卦象。君子观此卦象，取法于容纳江河的大地，收容和畜养大众。师即兵众，只有选择德高望重的长者来统率军队，才能吉祥无咎。忧劳动众，变化无穷；公正无私，排除万难。得此卦者，困难重重，忧心劳众，宜包容别人，艰苦努力，摒除一切困难。时运：包容别人，修行待时。财运：有财有库，善自珍惜。家宅：旧亲联姻，可喜可贺。身体：腹胀之症，调气无忧。这个卦是异卦（下坎上坤）相叠。“师”指军队。坎为水、为险；坤为地、为顺，喻寓兵于农。兵凶战危，用兵乃圣人不得已而为之，但它可以顺利无阻碍地解决矛盾，因为顺乎形势，师出有名，故能化凶为吉。",
#   "summary": "师卦在周易中，是一个极具深意的卦象。由两个异卦相叠组成：下卦坎（水）和上卦坤（地）。这一卦象代表“师”，即军队，寓意兵力和农力的结合。坎为水，代表危险；坤为地，代表顺从。师卦的核心哲学是兵凶战危，但其使用应当是圣人不得已而为之的最后手段。在正确的情况下，军事力量可以顺应形势，将危险转化为吉祥。",
#   "explanation": "师卦位于讼卦之后，《序卦》中解释为“讼必有众起，故受之以师”。这意味着争端激化至众多人群的参与，形成了类似军队的集体力量。在面临困难重重，忧心劳众的情况下，适宜包容别人，艰苦努力，摒除一切困难。在时运上，需要包容别人，修行待机。在财运、家宅、身体方面皆宜以正规行事，保持公正无私，排除万难。",
#   "prediction": "师卦的运势“困难重重”，需要与他人密切合作，谨小慎微，行为果断，避免盲目妄动，保全自己。在事业上，需要机动灵活，严于律已，在商业上要心怀高尚的商业道德，加强与他人的沟通，以此化解困境。在求名、婚恋、决策上则需要慎重、专注，不贪图小利，以中正为要，并且必要时要与他人合作，方可顺利成功。",
#   "scholar": "《断易天机》北宋易学家邵雍；《象辞》傅佩荣解；传统解卦
# Content: {
#   "content": "比卦",
#   "summary": "在周易中，比卦是一个吉利的卦象。它由下卦坤（地）上卦坎（水）组成，代表着再次卜筮之后仍然大吉大利，长期吉利无咎，但不宁愿来朝的邦国会有凶险。这一卦象显示了水附大地、地纳江河的亲密关系，预示着相亲相依、互相帮助、宽宏无私的道理。",
#   "interpretation": {
#     "general": "比卦说明在顺势而为，善待他人，可以获得贵人相助，宜直截了当地解决问题，不可过分犹豫。事业顺利发展，可以得到他人的支持和帮助，需要诚实、信任地对待他人，并向高尚的人学习。在经商上也是如此，需要诚实守信、真诚合作，否则会损失严重。对于求名、婚恋等方面，都预示着顺利、美好的姻缘和大发展。",
#     "career": {
#       "fortune": "事业顺利，能获得贵人提拔，不宜犹豫不决。"
#     },
#     "finance": {
#       "fortune": "可能实现愿望，但需与他人合作，注重商业道德。"
#     },
#     "relationship": {
#       "fortune": "美好姻缘，忠诚相爱，白头到老。"
#     },
#     "health": {
#       "fortune": "宜及时求医治疗。"
#     }
#   }
# }
# ``
# Summary: {
#   "content": "比卦",
#   "summary": "在周易中，比卦是一个吉利的卦象。它由下卦坤（地）上卦坎（水）组成，代表着再次卜筮之后仍然大吉大利，长期吉利无咎，但不宁愿来朝的邦国会有凶险。这一卦象显示了水附大地、地纳江河的亲密关系，预示着相亲相依、互相帮助、宽宏无私的道理。",
#   "interpretation": {
#     "general": "比卦说明在顺势而为，善待他人，可以获得贵人相助，宜直截了当地解决问题，不可过分犹豫。事业顺利发展，可以得到他人的支持和帮助，需要诚实、信任地对待他人，并向高尚的人学习。在经商上也是如此，需要诚实守信、真诚合作，否则会损失严重。对于求名、婚恋等方面，都预示着顺利、美好的姻缘和大发展。",
#     "career": {
#       "fortune": "事业顺利，能获得贵人提拔，不宜犹豫不决。"
#     },
#     "finance": {
#       "fortune": "可能实现愿望，但需与他人合作，注重商业道德。"
#     },
#     "relationship": {
#       "fortune": "美好姻缘，忠诚相爱，白头到老。"
#     },
#     "health": {
#       "fortune": "宜及时求医治疗。
# Content: 坤卦
# Summary: 坤卦是周易中的一卦，代表大吉大利的吉兆。这一卦象由坤上坤下组成，纯阴之性，象征着大地的柔顺和顺从天道的特质。占卜结果显示，雌马贞固预示着吉利。同时，预示着行走需先迷失，后才能找到主人，因此宜往西南旅行，此时可以得到朋友，但需注意东北可能会丧失朋友。对于定居而言，坤卦预示着吉祥。
#
# 在《象辞》中指出，坤卦的形势平铺舒展，君子应当取法于地，以深厚的德行来承担重大的责任。
#
# 坤卦的基本哲学是，顺从于天道，以柔顺的品质来承担万物，以德服人，自然无德者不敌。
#
# 坤卦的运势看似平静，但实质需要静待时机，不宜急进。在事业发展中，需谨慎行事，以静制动为宜。在求名、婚恋等方面，也宜以柔克刚，埋头苦干，不追求身外之物。对于经商者来说，不宜冒险，应以稳健为妥，待机而动，处处小心为是。
#
# 总的来说，坤卦预示着以柔克刚，以深厚的德行来化解困境，静待时机，不急于求成，埋头苦干，不追求身外之物。坤卦在不同方面的运势如同大地一般，顺从天道，具有深厚的道德和柔顺的品性。
# Content: {
#   "content": "乾卦",
#   "summary": "乾卦是《易经》六十四卦之首，象征天、喻龙。此卦为大吉大利之卦象，代表着兴盛和强健。根据万物变通的道理，乾卦教导人遵守天道的德行。乾卦的核心哲学是天行刚健，自强不息，表明大吉大利，但在顺利之际要保持警惕，避免骄傲和心浮气躁。",
#   "explanation": [
#     {
#       "title": "原文",
#       "content": "乾。元，亨，利，贞。\n象曰：天行健，君子以自强不息。"
#     },
#     {
#       "title": "断易天机解",
#       "content": "乾象征天，纯阳刚建，为大通而至正兆示。乾卦须行正道，方可永远亨通。"
#     },
#     {
#       "title": "北宋易学家邵雍解",
#       "content": "得此卦者名利双收之象，宜把握机会，争取成果。女性得此卦则有过于刚直之嫌。"
#     },
#     {
#       "title": "台湾国学大儒傅佩荣解",
#       "content": "时运临事刚健，自强不息。财运施比受有福，不宜买而利卖。家宅积善有余庆。身体保健有恒。"
#     },
#     {
#       "title": "传统解卦",
#       "content": "乾卦为大吉大利之卦象，象征着兴盛和强健。在顺利之际要保持警惕，避免骄傲和心浮气躁。"
#     }
#   ]
# }
# ``
# Summary: {
#   "content": "乾卦",
#   "summary": "乾卦是《易经》六十四卦之首，象征天、喻龙。此卦为大吉大利之卦象，代表着兴盛和强健。根据万物变通的道理，乾卦教导人遵守天道的德行。乾卦的核心哲学是天行刚健，自强不息，表明大吉大利，但在顺利之际要保持警惕，避免骄傲和心浮气躁。",
#   "explanation": [
#     {
#       "title": "原文",
#       "content": "乾。元，亨，利，贞。\n象曰：天行健，君子以自强不息。"
#     },
#     {
#       "title": "断易天机解",
#       "content": "乾象征天，纯阳刚建，为大通而至正兆示。乾卦须行正道，方可永远亨通。"
#     },
#     {
#       "title": "北宋易学家邵雍解",
#       "content": "得此卦者名利双收之象，宜把握机会，争取成果。女性得此卦则有过于刚直之嫌。"
#     },
#     {
#       "title": "台湾国学大儒傅佩荣解",
#       "content": "时运临事刚健，自强不息。财运施比受有福，不宜买而利卖。家宅积善有余庆。身体保健有恒。"
#     },
#     {
#       "title": "传统解卦",
#       "content": "乾卦为大吉大利之卦象，象征着兴盛和强健。在顺利之际要保持警惕，避免骄傲和心浮气躁。

# %% [markdown]
# ### 异常分析
# 训练第一个 epoch 时，Training Loss 比较奇怪：

# %% [raw]
# Step	Training Loss
# 1	3.594100
# 2	4.049100
# 3	3.091200
# 4	3.381700
# 5	3.547800
# 6	2.610200
# 7	2.657900
# 8	3.163900

# %% [markdown]
# #### 通过解析 GPT-3.5-Turbo-1106 生成结果发现问题

# %%
def gen_data(raw_content):
    """
    使用LangChain GPT-3.5调用处理单个数据样例。

    :param raw_content: 原始数据样例。
    :return: GPT-3.5模型生成的内容。
    """
    # 系统消息定义背景和任务
    system_message = SystemMessage(
        content="""
        你是中国古典哲学大师，尤其擅长周易的哲学解读。

        接下来，你收到的都是关于周易卦象的解释，你需要整理润色，并生成用于大模型训练的内容和格式。

        示例输入：

        师卦，此卦是异卦相叠，下卦为坎，上卦为坤。“师”指军队。坎为水、为险；坤为地、为顺，喻寓兵于农。兵凶战危，用兵乃圣人不得已而为之，但它可以顺利无阻碍地解决矛盾，因为顺乎形势，师出有名，故能化凶为吉。占得此卦，对于军事上率师出征非常有利，必无灾祸。师卦是天马出群之卦，以寡伏众之象。
        师卦位于讼卦之后，《序卦》之中这样解释道：“讼必有众起，故受之以师。师者，众也。”争讼的人越来越多，以致形成了军队。

        期待结果：

        content:"师卦"
        summary:"在周易中，师卦是一个极具深意的卦象，它由两个异卦相叠组成：下卦坎（水）和上卦坤（地）。这一卦象代表“师”，即军队，寓意着兵力和农力的结合。在这里，坎卦象征着水和险难，而坤卦象征着地和顺从，暗示着通过将军事力量安置于民间，可以在必要时顺利调动。

        师卦的核心哲学是：虽然兵力代表着危险和战争，但其使用应当是圣人不得已而为之的最后手段。在正确的情况下，军事力量可以顺应形势，将危险转化为吉祥。因此，在军事策略上，此卦象征着出征将会顺利，无灾祸。

        师卦紧随讼卦（争讼卦），在《序卦》中解释为“讼必有众起，故受之以师”。这意味着争端激化至众多人群的参与，形成了类似军队的集体力量。"

        返回格式要求：
        content:"{卦名}"
        summary:"{内容}"
        """
    )

    # 人类消息包含原始数据样例
    human_message = HumanMessage(
        content=raw_content
    )

    # 构建消息列表并进行模型调用
    messages = [system_message, human_message]
    ai_message = chat(messages)

    return ai_message.content

# %%
# 执行主函数
main()
# Out:
# Content: 蒙卦
# Summary: 在《易经》中，蒙卦是由坎卦上艮卦组成的异卦，坎象征水，艮象征山，所以形成了山下有水的卦象。蒙卦所代表的意义是：不是我有求于幼稚愚昧的人，而是幼稚愚昧的人有求于我。第一次占卜时，神灵告诉了他，但轻慢不敬的再三占卜，神灵就不会告诉他。然而，这依然是一个吉利的卜问。
#
# 蒙卦的核心哲学是：初时迷惑不知方向，需要忍耐待机而动，多听取别人意见，则运势可通。在事业上，需要勇敢坚毅的行动可以扭转局面，须接受严格教育，培养奋发图强的精神。务必脚踏实地，最忌好高骛远，否则会陷入孤立无援的境地。在经商上，务必小心谨慎，不得急功近利，尤其应树立高尚的商业道德，以良好的信誉提高竞争力而取胜。而在婚姻中，需要注意对方品德，不可以金钱为诱铒，夫妻需相互宽容、理解。决策上，需要接受长辈的教诲，甚至严酷的考验，抛弃疑惧的心理，等待适当时机，必然一帆风顺。
# Content: 屯卦
# Summary: 在周易中，屯卦是一个预示困难的卦象，由上卦坎（水）和下卦震（雷）组成。坎象征着云，震象征着雷，云行于上，雷动于下，象征着动而逢险境，需要刚强果断方能获得吉祥。
#
# 屯卦预示着万物始生时的艰难险阻，然而顺时应运，最终会欣欣向荣。在事业发展上，遇到困难不要退缩，而是应该勇往直前，灵活机动，务必需要他人的帮助。初始困难需要具有坚忍不拔的毅力和锲而不舍的奋斗精神，但最终能取得成就。
# Content: 需卦
# Summary: 在周易中，需卦代表着抓到俘虏的意象，象征着大吉大利和吉利的卜问。此卦有利于涉水渡河。上卦为坎，象征云；下卦为乾，象征天。云上于天，需。君子观此卦象，可以宴饮安乐，待时而动。需卦呈现踌躇、期待之象，虽然刚强，但前面有险阻，应当等待，涉大川则利。此卦提示时机尚未成熟，需要耐心等待。在事业上，需要审时度势，耐心等待，切勿冒险，欲速不达。当时机成熟后，必然一帆风顺。
# Content: 讼卦
# Summary: 讼卦，在周易中，讼卦是由乾（天）上坎（水）下组成的异卦。卦象暗示着有利可图，但需要警惕戒惧。在事情进行中会有一段吉利的时期，但最终会变得凶险。此卦象出现时，适宜会见贵族王公，但不适宜涉水渡河。
#
# 讼卦的象辞是乾卦（天）上坎卦（水）下，形成天与水违行的情景。君子观此卦象，以杜绝争讼为意，从而在谋事之初必须慎之又慎。讼卦的出现预示着争端的发生，需要慎重小心，避免争诉之事。
#
# 讼卦的解读暗示着事与愿违，事情不顺利，容易受到小人的加害，需要警惕陷阱。在事业上，起初顺利有利可图，但随后会受挫，务必慎之又慎，避免固执已见，尽量避免介入诉讼纠纷的争执之中。与其这样，不如退而让人，求得化解，安于正理，可免除意外之灾。在经商上，应坚持公正、公平、互利的原则，尽量避免冲突。在求名上，不利，应坚守纯正，隐忍自励，依靠有地位的人的帮助，及早渡过难关。在婚恋方面，双方应以温和的方式处理生活。在决策上，应知足、适可而止，接受教训，引以为戒，可功成名就。
# Content: 师卦
# Summary: 在周易中，师卦是一个极具深意的卦象，它由两个异卦相叠组成：下卦坎（水）和上卦坤（地）。这一卦象代表“师”，即军队，寓意着兵力和农力的结合。在这里，坎卦象征着水和险难，而坤卦象征着地和顺从，暗示着通过将军事力量安置于民间，可以在必要时顺利调动。
#
# 师卦的核心哲学是：虽然兵力代表着危险和战争，但其使用应当是圣人不得已而为之的最后手段。在正确的情况下，军事力量可以顺应形势，将危险转化为吉祥。因此，在军事策略上，此卦象征着出征将会顺利，无灾祸。
#
# 师卦紧随讼卦（争讼卦），在《序卦》中解释为“讼必有众起，故受之以师”。这意味着争端激化至众多人群的参与，形成了类似军队的集体力量。
#
# 而根据《象辞》，师卦的卦象是下坎上坤，形如“地中有水”，指示着军队的集结与畜养。由此可见，君子观此卦象，以容纳江河的大地为法则，包容和畜养大众，体现了对军民关系的体贴与管理。
#
# 整体而言，师卦暗示着遇到困难重重，必须包容别人、艰苦努力，并排除万难。在运势、财运、家宅、身体等方面，也提出了相应的忠告和预测。在事业、经商、求名、婚恋等方面，亦有着务实的意见和建议。总体而言，师卦是一个强调合作、谨慎行事，以及应对挑战的卦象，其哲学内涵适合于实际生活和处世应用。
# Content: 比卦
# Summary: 在周易中，比卦是一个吉利的卦象。它由坤卦（地）下，坎卦（水）上组成，象征着地上有水。这是一个描述相亲相辅、广阔无私、真诚团结的卦象，与师卦相反。比卦蕴含着长期亲密相处将会无灾无祸的吉祥之意。
#
# 据北宋易学家邵雍解释，比卦代表着水在地上流动，人际关系亲密欢乐，一切事情都能得心应手，无忧无虑。
#
# 传统解卦认为，比卦预示着平顺的运势，能够得到贵人的提拔，应该迅速决定行动，不可过分迟疑。在事业上，可获得成功并得到他人的帮助；而在经商上，若真诚交往，尊重商业道德，就能实现愿望且获得可观利润。在婚恋方面，表示美满的姻缘，相亲相爱，忠诚不渝。总的来说，比卦的核心理念是待人真诚、善良，乐于帮助他人，并且可以得到回报。
# Content: 坤卦
# Summary: 坤卦是周易中的一卦，象征大地的气息和顺应天道的品性。它由两个坤卦叠置而成，代表着顺从与坚韧。坤卦中的“君子有攸往，先迷后得主”意味着前路或许会困难，但最终会找到正确的出路。此卦吉利，宜于西南得朋，但行至东北则丧失朋友。在事业方面，坤卦暗示着须以静制动，不宜心急，需依靠他人的支持和合作。同时，坚持诚实待人，以柔克刚，不可贪功自傲，方能取得长久的成功。
# Content: 乾卦
# Summary: 在周易中，乾卦是六十四卦中的第一个卦，代表天之卦象，象征着大吉大利和吉利的贞卜。《象辞》中以天行健的形象，启发君子以自强不息。乾卦以纯阳刚建的形态示人，提示着行正道才可永远亨通。从北宋易学家邵雍的解读来看，乾卦意味着刚健旺盛，但需谨防太强。得此卦者宜把握机会，争取成果。然而，台湾国学大儒傅佩荣解读认为，乾卦所示自强不息的时运，施比受有福，但不宜买入而宜卖出。值得注意的是，在传统解卦中，乾卦被解释为大吉大利，心想事成，但也需小心谨慎，力戒骄傲，冷静处世。总的来说，乾卦所示的是顺利发展的大好机遇，但需以诚信和正直为道，才能充分发挥才智，保证事业成功。
